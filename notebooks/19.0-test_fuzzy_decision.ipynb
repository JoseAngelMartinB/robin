# %% [markdown]
# # Test Case - Fuzzy Passenger Decision Model

# %%
import os
import sys
sys.path.append('..')

SAVE_PATH = '../reports/figures/ewgt23/test_case_fuzzy'
os.makedirs(SAVE_PATH, exist_ok=True)

# %% [markdown]
# ## Simulate Passengers Demand

# %%
from src.robin.kernel.entities import Kernel

path_config_supply = '../configs/ewgt23/supply_data.yml'
path_config_demand = '../configs/ewgt23/demand_data_fuzzy.yml'
path_output_csv = '../data/ewgt23/output_fuzzy.csv'

os.makedirs('../data/ewgt23', exist_ok=True)
seed = 0

kernel = Kernel(path_config_supply, path_config_demand, seed)
services = kernel.simulate(output_path=path_output_csv, departure_time_hard_restriction=True)

# %% [markdown]
# ## Plot Results

# %%
from src.robin.plotter.entities import KernelPlotter

kernel_plotter = KernelPlotter(
    path_output_csv=path_output_csv,
    path_config_supply=path_config_supply
)

# %%
kernel_plotter.plotter_data_analysis()
# Out:
# Data from demand plot:
# 	Status: User bought a service which was not the one with the best utility. - Passengers: 4385
# 	Status: User found  any service that met his needs but couldn't purchase. - Passengers: 2952
# 	Status: User bought the ticket with best utility. - Passengers: 1873
# 	Status: User didn't find any ticket that met his needs. - Passengers: 0
#
# Data from pie chart:
# 	Total tickets sold:  6258
# 	Percentage of tickets sold by seat type:
# 		Seat: Básico - Passengers: 5316 - Percentage: 84.95 %
# 		Seat: Elige - Passengers: 692 - Percentage: 11.06 %
# 		Seat: Premium - Passengers: 250 - Percentage: 3.99 %
#
# Data from plot tickets sold by purchase day:
# 	Total tickets sold:  6258
# 	Tickets sold by purchase date and seat type:
# 		Date: 2023-08-23
# 			Seat: Básico - Number of tickets sold: 166
# 		Date: 2023-08-24
# 			Seat: Básico - Number of tickets sold: 163
# 			Seat: Elige - Number of tickets sold: 22
# 		Date: 2023-08-25
# 			Seat: Básico - Number of tickets sold: 133
# 			Seat: Elige - Number of tickets sold: 28
# 		Date: 2023-08-26
# 			Seat: Básico - Number of tickets sold: 113
# 			Seat: Elige - Number of tickets sold: 50
# 		Date: 2023-08-27
# 			Seat: Básico - Number of tickets sold: 175
# 		Date: 2023-08-28
# 			Seat: Básico - Number of tickets sold: 172
# 		Date: 2023-08-29
# 			Seat: Básico - Number of tickets sold: 168
# 		Date: 2023-08-30
# 			Seat: Básico - Number of tickets sold: 120
# 			Seat: Elige - Number of tickets sold: 50
# 		Date: 2023-08-31
# 			Seat: Básico - Number of tickets sold: 975
# 			Seat: Elige - Number of tickets sold: 27
# 			Seat: Premium - Number of tickets sold: 175
# 		Date: 2023-09-01
# 			Seat: Básico - Number of tickets sold: 817
# 			Seat: Elige - Number of tickets sold: 148
# 			Seat: Premium - Number of tickets sold: 61
# 		Date: 2023-09-02
# 			Seat: Básico - Number of tickets sold: 354
# 			Seat: Premium - Number of tickets sold: 14
# 		Date: 2023-09-03
# 			Seat: Básico - Number of tickets sold: 727
# 			Seat: Elige - Number of tickets sold: 1
# 		Date: 2023-09-04
# 			Seat: Básico - Number of tickets sold: 447
# 			Seat: Elige - Number of tickets sold: 149
# 		Date: 2023-09-05
# 			Seat: Básico - Number of tickets sold: 557
# 			Seat: Elige - Number of tickets sold: 85
# 		Date: 2023-09-06
# 			Seat: Básico - Number of tickets sold: 229
# 			Seat: Elige - Number of tickets sold: 132
#
# Data from plot tickets sold by purchase date, user and seat type:
# 	Total tickets sold:  6258
# 	Tickets sold by purchase date, user and seat type:
# 		Date: 2023-08-23
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 166
# 		Date: 2023-08-24
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 163
# 				Seat: Elige - Tickets sold: 22
# 		Date: 2023-08-25
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 133
# 				Seat: Elige - Tickets sold: 28
# 		Date: 2023-08-26
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 113
# 				Seat: Elige - Tickets sold: 50
# 		Date: 2023-08-27
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 175
# 		Date: 2023-08-28
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 172
# 		Date: 2023-08-29
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 168
# 		Date: 2023-08-30
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 120
# 				Seat: Elige - Tickets sold: 50
# 		Date: 2023-08-31
# 			User: Business
# 				Seat: Básico - Tickets sold: 814
# 				Seat: Premium - Tickets sold: 175
# 				Seat: Elige - Tickets sold: 25
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 161
# 				Seat: Elige - Tickets sold: 2
# 		Date: 2023-09-01
# 			User: Business
# 				Seat: Elige - Tickets sold: 100
# 				Seat: Premium - Tickets sold: 61
# 				Seat: Básico - Tickets sold: 686
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 131
# 				Seat: Elige - Tickets sold: 48
# 		Date: 2023-09-02
# 			User: Business
# 				Seat: Premium - Tickets sold: 14
# 				Seat: Básico - Tickets sold: 182
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 172
# 		Date: 2023-09-03
# 			User: Student
# 				Seat: Básico - Tickets sold: 513
# 				Seat: Elige - Tickets sold: 1
# 			User: Business
# 				Seat: Básico - Tickets sold: 55
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 159
# 		Date: 2023-09-04
# 			User: Student
# 				Seat: Elige - Tickets sold: 99
# 				Seat: Básico - Tickets sold: 342
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 105
# 				Seat: Elige - Tickets sold: 50
# 			User: Business
# 		Date: 2023-09-05
# 			User: Student
# 				Seat: Básico - Tickets sold: 420
# 				Seat: Elige - Tickets sold: 50
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 137
# 				Seat: Elige - Tickets sold: 35
# 		Date: 2023-09-06
# 			User: Student
# 				Seat: Elige - Tickets sold: 132
# 				Seat: Básico - Tickets sold: 229
#
# Data from plot tickets sold by pair of stations
# 	Total tickets sold:  6258
# 	Tickets sold by pair of stations:
# 		Pair: Madrid-Puerta de Atocha - Barcelona-Sants - Tickets: 3905
# 		Pair: Madrid-Puerta de Atocha - Zaragoza-Delicias - Tickets: 1373
# 		Pair: Zaragoza-Delicias - Barcelona-Sants - Tickets: 980

# %%
kernel_plotter.plot_demand_status(y_limit=7000, save_path=f'{SAVE_PATH}/demand_status.svg')

# %%
kernel_plotter.plot_seat_distribution_pie_chart(save_path=f'{SAVE_PATH}/pie.svg')

# %%
kernel_plotter.plot_tickets_by_date(save_path=f'{SAVE_PATH}/total_tickets_sold.svg')

# %%
kernel_plotter.plot_tickets_by_user(save_path=f'{SAVE_PATH}/tickets_sold_per_usertype.svg')

# %%
kernel_plotter.plot_service_capacity(
    service_id='03063_06-09-2023-06.30',
    save_path=f'{SAVE_PATH}/capacity_03063_06-09-2023-06.30.svg'
)

# %%
kernel_plotter.plot_service_capacity(
    service_id='06309_06-09-2023-19.30',
    save_path=f'{SAVE_PATH}/capacity_06309_06-09-2023-19.30.svg'
)

# %%
kernel_plotter.plot_service_capacity(
    service_id='03203_06-09-2023-20.40',
    save_path=f'{SAVE_PATH}/capacity_03203_06-09-2023-20.40.svg'
)

# %%
kernel_plotter.plot_tickets_by_pair(save_path=f'{SAVE_PATH}/pairs.svg')
