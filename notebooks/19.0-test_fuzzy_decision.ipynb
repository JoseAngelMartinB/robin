# %% [markdown]
# # Test Case - Fuzzy Passenger Decision Model

# %%
import os
import sys
sys.path.append('..')

SAVE_PATH = '../reports/figures/ewgt23/test_case_fuzzy'
os.makedirs(SAVE_PATH, exist_ok=True)

# %% [markdown]
# ## Simulate Passengers Demand

# %%
from src.robin.kernel.entities import Kernel

path_config_supply = '../configs/ewgt23/supply_data.yml'
path_config_demand = '../configs/ewgt23/demand_data_fuzzy.yml'
path_output_csv = '../data/ewgt23/output_fuzzy.csv'

os.makedirs('../data/ewgt23', exist_ok=True)
seed = 0

kernel = Kernel(path_config_supply, path_config_demand, seed)
services = kernel.simulate(output_path=path_output_csv, departure_time_hard_restriction=True)

# %% [markdown]
# ## Plot Results

# %%
from src.robin.plotter.entities import KernelPlotter

kernel_plotter = KernelPlotter(
    path_output_csv=path_output_csv,
    path_config_supply=path_config_supply
)

# %%
kernel_plotter.plotter_data_analysis()
# Out:
# Data from demand plot:
# 	Status: User bought a service which was not the one with the best utility. - Passengers: 4756
# 	Status: User found  any service that met his needs but couldn't purchase. - Passengers: 4095
# 	Status: User bought the ticket with best utility. - Passengers: 884
# 	Status: User didn't find any ticket that met his needs. - Passengers: 0
#
# Data from pie chart:
# 	Total tickets sold:  5640
# 	Percentage of tickets sold by seat type:
# 		Seat: Básico - Passengers: 5018 - Percentage: 88.97 %
# 		Seat: Elige - Passengers: 622 - Percentage: 11.03 %
#
# Data from plot tickets sold by purchase day:
# 	Total tickets sold:  5640
# 	Tickets sold by purchase date and seat type:
# 		Date: 2023-08-23
# 			Seat: Básico - Number of tickets sold: 173
# 			Seat: Elige - Number of tickets sold: 8
# 		Date: 2023-08-24
# 			Seat: Básico - Number of tickets sold: 177
# 			Seat: Elige - Number of tickets sold: 6
# 		Date: 2023-08-25
# 			Seat: Básico - Number of tickets sold: 144
# 			Seat: Elige - Number of tickets sold: 32
# 		Date: 2023-08-26
# 			Seat: Básico - Number of tickets sold: 144
# 			Seat: Elige - Number of tickets sold: 36
# 		Date: 2023-08-27
# 			Seat: Básico - Number of tickets sold: 139
# 			Seat: Elige - Number of tickets sold: 53
# 		Date: 2023-08-28
# 			Seat: Básico - Number of tickets sold: 168
# 			Seat: Elige - Number of tickets sold: 15
# 		Date: 2023-08-29
# 			Seat: Básico - Number of tickets sold: 178
# 		Date: 2023-08-30
# 			Seat: Básico - Number of tickets sold: 201
# 		Date: 2023-08-31
# 			Seat: Básico - Number of tickets sold: 756
# 			Seat: Elige - Number of tickets sold: 250
# 		Date: 2023-09-01
# 			Seat: Básico - Number of tickets sold: 381
# 		Date: 2023-09-02
# 			Seat: Básico - Number of tickets sold: 228
# 			Seat: Elige - Number of tickets sold: 50
# 		Date: 2023-09-03
# 			Seat: Básico - Number of tickets sold: 657
# 		Date: 2023-09-04
# 			Seat: Básico - Number of tickets sold: 652
# 		Date: 2023-09-05
# 			Seat: Básico - Number of tickets sold: 598
# 			Seat: Elige - Number of tickets sold: 100
# 		Date: 2023-09-06
# 			Seat: Básico - Number of tickets sold: 422
# 			Seat: Elige - Number of tickets sold: 72
#
# Data from plot tickets sold by purchase date, user and seat type:
# 	Total tickets sold:  5640
# 	Tickets sold by purchase date, user and seat type:
# 		Date: 2023-08-23
# 			User: Tourist
# 				Seat: Elige - Tickets sold: 8
# 				Seat: Básico - Tickets sold: 173
# 		Date: 2023-08-24
# 			User: Tourist
# 				Seat: Elige - Tickets sold: 6
# 				Seat: Básico - Tickets sold: 177
# 		Date: 2023-08-25
# 			User: Tourist
# 				Seat: Elige - Tickets sold: 32
# 				Seat: Básico - Tickets sold: 144
# 		Date: 2023-08-26
# 			User: Tourist
# 				Seat: Elige - Tickets sold: 36
# 				Seat: Básico - Tickets sold: 144
# 		Date: 2023-08-27
# 			User: Tourist
# 				Seat: Elige - Tickets sold: 53
# 				Seat: Básico - Tickets sold: 139
# 		Date: 2023-08-28
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 168
# 				Seat: Elige - Tickets sold: 15
# 		Date: 2023-08-29
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 178
# 		Date: 2023-08-30
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 201
# 		Date: 2023-08-31
# 			User: Business
# 				Seat: Básico - Tickets sold: 638
# 				Seat: Elige - Tickets sold: 190
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 118
# 				Seat: Elige - Tickets sold: 60
# 		Date: 2023-09-01
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 166
# 			User: Business
# 				Seat: Básico - Tickets sold: 215
# 		Date: 2023-09-02
# 			User: Business
# 				Seat: Básico - Tickets sold: 95
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 133
# 				Seat: Elige - Tickets sold: 50
# 		Date: 2023-09-03
# 			User: Student
# 				Seat: Básico - Tickets sold: 499
# 			User: Business
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 158
# 		Date: 2023-09-04
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 179
# 			User: Business
# 			User: Student
# 				Seat: Básico - Tickets sold: 473
# 		Date: 2023-09-05
# 			User: Student
# 				Seat: Básico - Tickets sold: 477
# 				Seat: Elige - Tickets sold: 50
# 			User: Tourist
# 				Seat: Básico - Tickets sold: 121
# 				Seat: Elige - Tickets sold: 50
# 		Date: 2023-09-06
# 			User: Student
# 				Seat: Básico - Tickets sold: 422
# 				Seat: Elige - Tickets sold: 72
#
# Data from plot tickets sold by pair of stations
# 	Total tickets sold:  5640
# 	Tickets sold by pair of stations:
# 		Pair: Madrid-Puerta de Atocha - Barcelona-Sants - Tickets: 3342
# 		Pair: Madrid-Puerta de Atocha - Zaragoza-Delicias - Tickets: 1429
# 		Pair: Zaragoza-Delicias - Barcelona-Sants - Tickets: 869

# %%
kernel_plotter.plot_demand_status(y_limit=7000, save_path=f'{SAVE_PATH}/demand_status.svg')

# %%
kernel_plotter.plot_seat_distribution_pie_chart(save_path=f'{SAVE_PATH}/pie.svg')

# %%
kernel_plotter.plot_tickets_by_date(save_path=f'{SAVE_PATH}/total_tickets_sold.svg')

# %%
kernel_plotter.plot_tickets_by_user(save_path=f'{SAVE_PATH}/tickets_sold_per_usertype.svg')

# %%
kernel_plotter.plot_service_capacity(
    service_id='03063_06-09-2023-06.30',
    save_path=f'{SAVE_PATH}/capacity_03063_06-09-2023-06.30.svg'
)

# %%
kernel_plotter.plot_service_capacity(
    service_id='06309_06-09-2023-19.30',
    save_path=f'{SAVE_PATH}/capacity_06309_06-09-2023-19.30.svg'
)

# %%
kernel_plotter.plot_service_capacity(
    service_id='03203_06-09-2023-20.40',
    save_path=f'{SAVE_PATH}/capacity_03203_06-09-2023-20.40.svg'
)

# %%
kernel_plotter.plot_tickets_by_pair(save_path=f'{SAVE_PATH}/pairs.svg')
