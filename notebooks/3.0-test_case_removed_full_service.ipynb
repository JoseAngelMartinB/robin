# %% [markdown]
# # Test Case - What if a full service gets removed?

# %%
import os
import sys
sys.path.append('..')

SAVE_PATH = '../reports/figures/test_case_removed_full_service'
os.makedirs(SAVE_PATH, exist_ok=True)

# %% [markdown]
# ## Simulate Passengers Demand

# %%
from src.robin.kernel.entities import Kernel

path_config_supply = '../configs/test_case/supply_data_removed_full_service.yml'
path_config_demand = '../configs/test_case/demand_data.yml'
path_output_csv = '../data/test_case/output_removed_full_service.csv'

os.makedirs('../data/test_case', exist_ok=True)
seed = 0

kernel = Kernel(path_config_supply, path_config_demand, seed)
services = kernel.simulate(output_path=path_output_csv, departure_time_hard_restriction=True)

# %% [markdown]
# ## Plot Results

# %%
from src.robin.plotter.entities import KernelPlotter

kernel_plotter = KernelPlotter(
    path_output_csv=path_output_csv,
    path_config_supply=path_config_supply
)

# %%
kernel_plotter.plot_tickets_sold_pie_chart(save_path=f'{SAVE_PATH}/pie.png')

# %%
kernel_plotter.plot_tickets_sold(save_path=f'{SAVE_PATH}/total_tickets_sold.png')

# %%
kernel_plotter.plot_tickets_sold_by_user(save_path=f'{SAVE_PATH}/tickets_sold_per_usertype.png')

# %%
kernel_plotter.plot_capacity(service_id='03063_01-06-2023-06.30', save_path=f'{SAVE_PATH}/capacity_03063_01-06-2023-06.30.png')

# %%
kernel_plotter.plot_capacity(service_id='06309_01-06-2023-19.30', save_path=f'{SAVE_PATH}/capacity_06309_01-06-2023-19.30.png')

# %%
kernel_plotter.plot_capacity(service_id='03203_01-06-2023-20.40', save_path=f'{SAVE_PATH}/capacity_03203_01-06-2023-20.40.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 kernel_plotter.plot_capacity(service_id='03203_01-06-2023-20.40', save_path=f'{SAVE_PATH}/capacity_03203_01-06-2023-20.40.png')
#
# File ~/PycharmProjects/robin/src/robin/plotter/entities.py:230, in KernelPlotter.plot_capacity(self, service_id, save_path)
#     222 def plot_capacity(self, service_id: Union[int, str], save_path: str = None):
#     223     """
#     224     Plot the capacity of the service grouped by departure, arrival station and purchase day.
#     225
#    (...)
#     228         save_path (str, optional): Path to save the plot. Defaults to None.
#     229     """
# --> 230     data = self._get_service_capacity(service_id)
#     231     self._plot_bar_chart(data, title=f'Capacidad para el servicio {service_id}', xlabel='Estación', ylabel='Tickets', rotation=25, save_path=save_path)
#
# File ~/PycharmProjects/robin/src/robin/plotter/entities.py:117, in KernelPlotter._get_service_capacity(self, service_id)
#     115 # Filter the service
#     116 service = self.supply.filter_service_by_id(service_id)
# --> 117 stations_tickets = {station.id: () for station in service.line.stations}
#     119 # Calculate the total capacity of each station
#     120 for i, station in enumerate(stations_tickets):
#
# AttributeError: 'NoneType' object has no attribute 'line'

# %%
kernel_plotter.plot_capacity(service_id='03143_01-06-2023-14.30', save_path=f'{SAVE_PATH}/capacity_03143_01-06-2023-14.30.png')

# %%
kernel_plotter.plot_pairs(save_path=f'{SAVE_PATH}/pairs.png')
