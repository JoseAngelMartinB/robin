# %%
import os
import sys
sys.path.append('..')

SAVE_PATH = '../reports/figures/test_kernel_plotter'
os.makedirs(SAVE_PATH, exist_ok=True)

# %%
from src.robin.plotter.entities import KernelPlotter

kernel_plotter = KernelPlotter(
    path_output_csv='../data/kernel_output/output.csv',
    path_config_supply='../configs/supply_data.yml'
)

# %%
kernel_plotter.plot_tickets_sold_pie_chart(save_path=f'{SAVE_PATH}/pie.png')

# %%
kernel_plotter.plot_tickets_sold(save_path=f'{SAVE_PATH}/total_tickets_sold.png')

# %%
kernel_plotter.plot_tickets_by_user(save_path=f'{SAVE_PATH}/tickets_sold_per_usertype.png')

# %%
kernel_plotter.plot_capacity(service_id='03211_16-03-2023-21.10', save_path=f'{SAVE_PATH}/capacity.png')

# %%
kernel_plotter.plot_pairs(save_path=f'{SAVE_PATH}/pairs.png')
